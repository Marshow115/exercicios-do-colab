# %% [markdown]
# <a href="https://colab.research.google.com/github/Marshow115/exercicios-do-colab/blob/main/atividades_pythom.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Exercicios de programação

1.faça um algoritimo para ler dois numeros que dê o resultado da soma
# Out:
#   File "/tmp/ipykernel_1048/683509699.py", line 3
#     1.faça um algoritimo para ler dois numeros que dê o resultado da soma
#      ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# ## algoritimo
#
# 1. leia o primeiro numero e guarde na variavel chamada "n1"
# 2. leia o segundo numero e guarde na variavel chamada "n2"
# 3. faça uma soma das duas variaveis e guarde o resultado em outra variavel chamada soma
# 4. mostre o resultado

# %%
idade1 = 19
nome2 = 'vinicius'
print(f'meu nome é {nome2} e tenho {idade1}')
# Out:
# meu nome é vinicius e tenho 19

# %%
numero01 = int(input("digite valor de X:"))
numero02 = int(input("digite valor de Y:"))
soma = numero01 + numero02
print(f"o resultado é {soma}")
# Out:
# digite valor de X:4
# digite valor de Y:4
# o resultado é 8

# %%
n1 = int(input('digite um numero:'))
n2 = int(input('digite um numero:'))
n3 = int(input('digite um numero:'))

soma = n1 + n2 + n3
print(f"o resultado da soma é {soma}")
média = soma / 3
print(f"o resultado da média é {média}")
produto = n1 * n2 * n3
print(f"o resultado do produto é {produto}")
# Out:
# digite um numero:2
# digite um numero:3
# digite um numero:4
# o resultado da soma é 9
# o resultado da média é 3.0
# o resultado do produto é 24

# %%
n1 = float(input('digite um numero:'))
n2 = float(input('digite um numero:'))

if   n1 > n2:
    print(f'o numero maior é {n1}')
    print(f'o numeron menor é {n2}')

elif n1 < n2:
    print(f'o numero maior é {n2}')
    print(f'o numeron menor é {n1}')

else:
    print(f'os valores são iguais...')
# Out:
# digite um numero:3
# digite um numero:3
# os valores são iguais...

# %%
n1 = int(input('digite um numero:'))
n2 = int(input('digite um numero:'))

if n1 % 2 == 0:
    print(f'o numero {n1} é par')
else:
    print(f'o numero {n1} é impar')
# Out:
# digite um numero:2
# digite um numero:5
# o numero 2 é par
